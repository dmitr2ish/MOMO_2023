# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitr2ish/MOMO_2023/blob/main/Python_%D0%B4%D0%BB%D1%8F_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0_%D0%B8_%D0%B2%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D0%B8_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Цель Блокнота

# %% [markdown]
# Применение библиотеки pandas для анализа табличных данных
# * Считывание данных из файла
# * Анализ базовой информации о данных
# * Анализ числовых и категориальных данных
#
# Применение библиотек seaborn и matplotlib для визуализации данных

# %% [markdown]
# # Набор данных
#
# **Оценка стоимости  и типа трансмиссии по данным продаж автомобилей на вторичном рынке Молдавии**

# %% [markdown]
# Набор данных представляет собой статистику параметров автомобилей на вторичном рынке в Молдавии.
#
# Набор включает ряд категориальных и численных значений, составляющих одну запись (строку). Число записей можно найти как число строк.
#
# Каждый столбец в записи — это отдельный признак.

# %% [markdown]
# # Import библиотек

# %% [markdown]
# Обычно все импортируемы библиотеки размещаются в самом начале
#
# Но мы будем импортировать постепенно

# %% [markdown]
# # Библиотека Pandas для работы с Табличными данными

# %%
#↓ ключевое слово "импортируй"
#↓     ↓ название библиотеки
#↓     ↓         ↓ сокращенное название чтобы использовать в коде
import pandas as pd # Библиотека Pandas для работы с табличными данными

# %% [markdown]
# Каждая уважающая себя Библиотека имеет подробную документацию
#
# [Pandas не исключение](https://pandas.pydata.org/)

# %% [markdown]
# ## Считываем файл в DataFrame

# %% [markdown]
# функция `.read_csv(path,delimiter) `
#
# * `path` путь к файлу + имя файла
# * `delimiter` разделитель

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dayekb/mpti_ml/main/data/cars.csv',
                 delimiter = ',') # можно считывать открытые файлы из интернета

# %% [markdown]
# В результате в переменную `df` класс DataFrame на основе считанного файла

# %%
df # в блокнотах Colab если запустить ячеку с переменной, то будет визуализирована эта переменная
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# ...           ...           ...   ...        ...       ...
# 41002       Dacia     Logan Mcv  2015  Universal   89000.0
# 41003     Renault         Modus  2009  Hatchback     225.0
# 41004    Mercedes       E Class  2016      Sedan   50000.0
# 41005       Mazda             6  2006      Combi  370000.0
# 41006     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# 2                    1400.0        Petrol       Manual       2200.0
# 3                    1500.0        Diesel       Manual       6550.0
# 4                    1600.0  Metan/Propan       Manual       4100.0
# ...                     ...           ...          ...          ...
# 41002                1500.0        Diesel       Manual       7000.0
# 41003                1500.0        Diesel       Manual       4500.0
# 41004                1950.0        Diesel    Automatic      29500.0
# 41005                2000.0        Diesel       Manual       4000.0
# 41006                1500.0        Diesel       Manual       4000.0
#
# [41007 rows x 9 columns]

# %% [markdown]
# ## Информация о DataFrame

# %% [markdown]
# Метод `.info() `

# %%
df.info() # информация о данных в DataFrame:
#сколько строк,
#какие данные в столбцах,
#сколько пропущенных значений (Nan-values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 41007 non-null  object
#  2   Year                  41007 non-null  int64
#  3   Style                 41007 non-null  object
#  4   Distance              41007 non-null  float64
#  5   Engine_capacity(cm3)  41007 non-null  float64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          41007 non-null  object
#  8   Price(euro)           41007 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Поиск Дубликатов

# %% [markdown]
# методы `.duplicated()` и `.sum()`

# %%
df.duplicated().sum() # метод .duplicated() возвращает данные в бинарном виде: является ли отдельная строка дубликатом (True если является)
#Просуммировав мы узнаем сколько всего дубликатов
# Out:
# 3743

# %% [markdown]
# **Удаление дубликатов**
#
# Методы `.drop_duplicates()` и `.reset_index()`

# %%
DF = df.drop_duplicates() # Складываем в новый DataFrame результат удаления дубликатов

DF = DF.reset_index(drop=True) # обновим индексы в DataFrame DF.
# если бы мы прописали drop = False, то была бы еще одна колонка - старые индексы

DF
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# 2                    1400.0        Petrol       Manual       2200.0
# 3                    1500.0        Diesel       Manual       6550.0
# 4                    1600.0  Metan/Propan       Manual       4100.0
# ...                     ...           ...          ...          ...
# 37259                1800.0  Metan/Propan       Manual       4400.0
# 37260                1500.0        Diesel       Manual       7000.0
# 37261                1500.0        Diesel       Manual       4500.0
# 37262                2000.0        Diesel       Manual       4000.0
# 37263                1500.0        Diesel       Manual       4000.0
#
# [37264 rows x 9 columns]

# %%
DF.duplicated().sum() # проверили что дубликатов нет
# Out:
# 0

# %% [markdown]
# ## Сохранение DataFrame в файл

# %% [markdown]
# Метод `.to_csv(path, index)`

# %%
DF.to_csv('/content/cars_moldova_no_dup.csv',index=False) # если хотим чтобы и индексы сохранились - пишем index = True

# %% [markdown]
# ## Индексация

# %% [markdown]
# **Визуализация части DataFrame**
#
# Метод `.head(n)` - первые `n` строк

# %%
DF.head(6)
# Out:
#          Make         Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 0      Toyota         Prius  2011  Hatchback  195000.0                1800.0
# 1     Renault  Grand Scenic  2014  Universal  135000.0                1500.0
# 2  Volkswagen          Golf  1998  Hatchback       1.0                1400.0
# 3     Renault        Laguna  2012  Universal  110000.0                1500.0
# 4        Opel         Astra  2006  Universal  200000.0                1600.0
# 5    Mercedes          Vito  2000   Microvan  300000.0                2200.0
#
#       Fuel_type Transmission  Price(euro)
# 0        Hybrid    Automatic       7750.0
# 1        Diesel       Manual       8550.0
# 2        Petrol       Manual       2200.0
# 3        Diesel       Manual       6550.0
# 4  Metan/Propan       Manual       4100.0
# 5        Diesel       Manual       3490.0

# %% [markdown]
# Метод `.tail(n)` - последние `n` строк

# %%
DF.tail(9)
# Out:
#              Make         Model  Year      Style  Distance  \
# 37255     Renault        Megane  2011      Sedan  145000.0
# 37256      Toyota         Auris  2007  Hatchback  222111.0
# 37257       Skoda        Superb  2016  Cabriolet   78900.0
# 37258  Volkswagen        Passat  2016      Sedan   88000.0
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 37255                1500.0        Diesel    Automatic       6200.0
# 37256                1400.0        Diesel    Automatic       4444.0
# 37257                2000.0        Petrol    Automatic      21000.0
# 37258                1800.0        Petrol    Automatic      11500.0
# 37259                1800.0  Metan/Propan       Manual       4400.0
# 37260                1500.0        Diesel       Manual       7000.0
# 37261                1500.0        Diesel       Manual       4500.0
# 37262                2000.0        Diesel       Manual       4000.0
# 37263                1500.0        Diesel       Manual       4000.0

# %% [markdown]
# Метод `.sample(n)` - случаы `n` строк

# %%
DF.head(6)
# Out:
#          Make         Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 0      Toyota         Prius  2011  Hatchback  195000.0                1800.0
# 1     Renault  Grand Scenic  2014  Universal  135000.0                1500.0
# 2  Volkswagen          Golf  1998  Hatchback       1.0                1400.0
# 3     Renault        Laguna  2012  Universal  110000.0                1500.0
# 4        Opel         Astra  2006  Universal  200000.0                1600.0
# 5    Mercedes          Vito  2000   Microvan  300000.0                2200.0
#
#       Fuel_type Transmission  Price(euro)
# 0        Hybrid    Automatic       7750.0
# 1        Diesel       Manual       8550.0
# 2        Petrol       Manual       2200.0
# 3        Diesel       Manual       6550.0
# 4  Metan/Propan       Manual       4100.0
# 5        Diesel       Manual       3490.0

# %% [markdown]
# **Индексация**
#
# аттрибут `.loc[строки, столбцы]`

# %%
DF.loc[1437,'Transmission'] # конкретная ячейка
# Out:
# 'Automatic'

# %%
DF.loc[:,'Transmission'] # столбец в формате Series
# Out:
# 0        Automatic
# 1           Manual
# 2           Manual
# 3           Manual
# 4           Manual
#            ...
# 37259       Manual
# 37260       Manual
# 37261       Manual
# 37262       Manual
# 37263       Manual
# Name: Transmission, Length: 37264, dtype: object

# %%
DF.loc[:,['Transmission']].head(5) # столбец в формате DataFrame
# Out:
#   Transmission
# 0    Automatic
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual

# %%
DF.loc[:,['Transmission','Year']].head(5) #несколько столбцов перечислением
# Out:
#   Transmission  Year
# 0    Automatic  2011
# 1       Manual  2014
# 2       Manual  1998
# 3       Manual  2012
# 4       Manual  2006

# %%
DF.loc[:,'Make':'Style'].head(5) #несколько столбцов в формате "от" и "до"
# Out:
#          Make         Model  Year      Style
# 0      Toyota         Prius  2011  Hatchback
# 1     Renault  Grand Scenic  2014  Universal
# 2  Volkswagen          Golf  1998  Hatchback
# 3     Renault        Laguna  2012  Universal
# 4        Opel         Astra  2006  Universal

# %%
DF.loc[69,:] # строка в формате Серий (Series)
# Out:
# Make                        Honda
# Model                        CR-V
# Year                         2002
# Style                   Universal
# Distance                 275100.0
# Engine_capacity(cm3)       2000.0
# Fuel_type                  Petrol
# Transmission               Manual
# Price(euro)                5900.0
# Name: 69, dtype: object

# %%
DF.loc[69:69,:] # строка в формате DataFrame
# Out:
#      Make Model  Year      Style  Distance  Engine_capacity(cm3) Fuel_type  \
# 69  Honda  CR-V  2002  Universal  275100.0                2000.0    Petrol
#
#    Transmission  Price(euro)
# 69       Manual       5900.0

# %%
DF.loc[322:1437,:] # несколько строк
# Out:
#           Make     Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 322      Skoda   Octavia  2010  Universal       1.0                1400.0
# 323   Mercedes   E Class  2016      Sedan  161024.0                2200.0
# 324      Honda     Civic  2006  Hatchback  195000.0                1400.0
# 325       Ford    Fusion  2015      Sedan  124000.0                2000.0
# 326       Ford    Fusion  2003  Hatchback  330000.0                1400.0
# ...        ...       ...   ...        ...       ...                   ...
# 1433   Peugeot       208  2013  Hatchback  154000.0                1400.0
# 1434  Infiniti      QX30  2017        SUV   91000.0                1500.0
# 1435      Ford      Kuga  2016        SUV  102500.0                1500.0
# 1436      Ford      Kuga  2018        SUV  122100.0                1500.0
# 1437       BMW  3 Series  2016      Sedan   64000.0                2000.0
#
#            Fuel_type Transmission  Price(euro)
# 322           Petrol       Manual       5350.0
# 323           Diesel    Automatic      26950.0
# 324           Petrol       Manual       5400.0
# 325   Plug-in Hybrid    Automatic      11499.0
# 326           Diesel    Automatic       4100.0
# ...              ...          ...          ...
# 1433          Diesel    Automatic       6999.0
# 1434          Diesel    Automatic      15490.0
# 1435          Diesel       Manual      14490.0
# 1436          Diesel       Manual      14250.0
# 1437          Petrol    Automatic      17500.0
#
# [1116 rows x 9 columns]

# %%
DF.loc[227:229,'Make':'Fuel_type'] #некоторые столбцы и строки
# Out:
#         Make    Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 227     Opel  Calibra  1992      Coupe  400000.0                2000.0
# 228  Renault   Kadjar  2016  Crossover  150425.0                1500.0
# 229     Ford   Fusion  2018      Sedan  105000.0                2000.0
#
#         Fuel_type
# 227  Metan/Propan
# 228        Diesel
# 229        Hybrid

# %% [markdown]
# **Логическое Индексирование**

# %%
DF[DF['Transmission']=='Manual'] # можно ставить произвольные условия
# Out:
#              Make         Model  Year      Style  Distance  \
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# 5        Mercedes          Vito  2000   Microvan  300000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 1                    1500.0        Diesel       Manual       8550.0
# 2                    1400.0        Petrol       Manual       2200.0
# 3                    1500.0        Diesel       Manual       6550.0
# 4                    1600.0  Metan/Propan       Manual       4100.0
# 5                    2200.0        Diesel       Manual       3490.0
# ...                     ...           ...          ...          ...
# 37259                1800.0  Metan/Propan       Manual       4400.0
# 37260                1500.0        Diesel       Manual       7000.0
# 37261                1500.0        Diesel       Manual       4500.0
# 37262                2000.0        Diesel       Manual       4000.0
# 37263                1500.0        Diesel       Manual       4000.0
#
# [20723 rows x 9 columns]

# %%
DF[(DF['Transmission']=='Manual') & (DF['Year']>2000)] #пример как объединить два условия вместе
# Out:
#              Make         Model  Year      Style  Distance  \
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# 6      Volkswagen        Passat  2010  Universal  290000.0
# 9             BMW      5 Series  2004      Sedan  325000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 1                    1500.0        Diesel       Manual       8550.0
# 3                    1500.0        Diesel       Manual       6550.0
# 4                    1600.0  Metan/Propan       Manual       4100.0
# 6                    1390.0        Petrol       Manual       5600.0
# 9                     300.0        Diesel       Manual       3400.0
# ...                     ...           ...          ...          ...
# 37259                1800.0  Metan/Propan       Manual       4400.0
# 37260                1500.0        Diesel       Manual       7000.0
# 37261                1500.0        Diesel       Manual       4500.0
# 37262                2000.0        Diesel       Manual       4000.0
# 37263                1500.0        Diesel       Manual       4000.0
#
# [15562 rows x 9 columns]

# %% [markdown]
# ## Сортировка DataFrame

# %% [markdown]
# Метод `.sort_values(by)`
#
# `by` - по какой колонке сортируем

# %%
DF.sort_values(by = 'Price(euro)').head(5) # по возрастанию
# Out:
#              Make          Model  Year      Style   Distance  \
# 18658        Opel       Frontera  1999        SUV      296.0
# 19867    Mercedes  Series (W124)  1989  Universal     1111.0
# 5077         Audi             A6  2004  Universal    12345.0
# 14463  Alta marca      Alt model  1997  Crossover  1999922.0
# 14547         Vaz         Altele  1989  Universal   199888.0
#
#        Engine_capacity(cm3) Fuel_type Transmission  Price(euro)
# 18658                2200.0    Diesel    Automatic          1.0
# 19867                3000.0    Diesel    Automatic          1.0
# 5077                 2500.0    Diesel       Manual          1.0
# 14463                1600.0    Petrol       Manual          5.0
# 14547                1300.0    Petrol       Manual          5.0

# %% [markdown]
# Метод `.sort_values(by, ascending= False)`

# %%
DF.sort_values(by = 'Year', ascending= False).head(5) # по убыванию
# Out:
#              Make      Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 29164        Audi         A5  2021      Sedan     661.0                2000.0
# 32583    Mercedes  GLS Klass  2021        SUV       0.0                3000.0
# 15611  Volkswagen       Polo  2021  Universal  280000.0                1400.0
# 6044        Skoda     Superb  2021      Sedan       0.0                1500.0
# 11840      Toyota    Corolla  2021  Universal     288.0                1987.0
#
#       Fuel_type Transmission  Price(euro)
# 29164    Petrol    Automatic      32200.0
# 32583    Diesel    Automatic     107528.0
# 15611    Petrol       Manual       1900.0
# 6044     Petrol    Automatic      30000.0
# 11840    Hybrid    Automatic      23000.0

# %% [markdown]
# Можно по нескольким колонкам сразу

# %%
DF.sort_values(by = ['Price(euro)','Engine_capacity(cm3)'],
               ascending=[True, False]).head(5)
# Out:
#              Make          Model  Year      Style   Distance  \
# 19867    Mercedes  Series (W124)  1989  Universal     1111.0
# 5077         Audi             A6  2004  Universal    12345.0
# 18658        Opel       Frontera  1999        SUV      296.0
# 14463  Alta marca      Alt model  1997  Crossover  1999922.0
# 14478  Alta marca      Alt model  1992      Sedan   192222.0
#
#        Engine_capacity(cm3) Fuel_type Transmission  Price(euro)
# 19867                3000.0    Diesel    Automatic          1.0
# 5077                 2500.0    Diesel       Manual          1.0
# 18658                2200.0    Diesel    Automatic          1.0
# 14463                1600.0    Petrol       Manual          5.0
# 14478                1300.0    Petrol       Manual          5.0

# %% [markdown]
# Сначала сортирует по первой, потом по второй

# %%
DF.sort_values(by = ['Engine_capacity(cm3)', 'Price(euro)'],
               ascending=[True, True]).head(5)
# Out:
#              Make    Model  Year    Style  Distance  Engine_capacity(cm3)  \
# 3259         Ford  Scorpio  1990    Sedan  100000.0                   0.0
# 31730  Volkswagen    Jetta  1985    Sedan       0.0                   0.0
# 36128      Nissan  Primera  1993      SUV       0.0                   0.0
# 21037         Vaz     2104  1986  Minivan  100000.0                   0.0
# 32324   Chevrolet     Aveo  2006    Sedan       0.0                   0.0
#
#           Fuel_type Transmission  Price(euro)
# 3259         Petrol       Manual        500.0
# 31730        Petrol       Manual        500.0
# 36128  Metan/Propan       Manual        700.0
# 21037  Metan/Propan       Manual        850.0
# 32324  Metan/Propan       Manual       1200.0

# %% [markdown]
# посмотрим на то, какие у нас есть категориальные и численные столбцы

# %%
cat_columns = [] # создаем пустой список для имен колонок категориальных данных
num_columns = [] # создаем пустой список для имен колонок числовых данных

for column_name in DF.columns: # смотрим на все колонки в DataFrame
    if (DF[column_name].dtypes == object): # проверяем тип данных для каждой колонки
        cat_columns +=[column_name] # если тип объект - то складываем в категориальные данные
    else:
        num_columns +=[column_name] # иначе - числовые

# важно: если признак категориальный, но хранится в формате числовых данных, тогда код не сработает корректно

# выводим результат
print('Категориальные данные:\t ',cat_columns, '\n Число столблцов = ',len(cat_columns))

print('Числовые данные:\t ',  num_columns, '\n Число столблцов = ',len(num_columns))
# Out:
# Категориальные данные:	  ['Make', 'Model', 'Style', 'Fuel_type', 'Transmission']
#  Число столблцов =  5
# Числовые данные:	  ['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)']
#  Число столблцов =  4

# %% [markdown]
# ## Анализ числовых признаков

# %% [markdown]
# Статистика по числовым данным
#
# метод `.describe()`

# %%
DF.describe() # посчитает "стандартные" статистические параметры для числовых данных
# если данные с типом отличных от числовых - то они проигнорируются
# Out:
#                Year      Distance  Engine_capacity(cm3)   Price(euro)
# count  37264.000000  3.726400e+04          37264.000000  3.726400e+04
# mean    2007.709264  4.758488e+05           1858.932535  9.569387e+03
# std        8.295806  4.591520e+06            707.662731  5.283315e+04
# min     1900.000000  0.000000e+00              0.000000  1.000000e+00
# 25%     2004.000000  9.000000e+04           1499.000000  3.300000e+03
# 50%     2009.000000  1.700000e+05           1800.000000  6.490000e+03
# 75%     2014.000000  2.300000e+05           2000.000000  1.179900e+04
# max     2021.000000  1.000000e+08           9999.000000  1.000000e+07

# %% [markdown]
# ### Агрегация
#
# К DataFrame применяется метод `.groupby()` с указанием (по чему группировать), а затем то, что хотим посчитать по группе (в данном случае `.mean()`)

# %%
DF.groupby(['Transmission'],).mean(num_columns)
# Out:
#                      Year       Distance  Engine_capacity(cm3)   Price(euro)
# Transmission
# Automatic     2011.170788  267131.045584           2136.525966  14657.392358
# Manual        2004.946292  642446.333784           1637.358780   5508.166144

# %% [markdown]
# Или даже более сложная статистика
#
# К DataFrame применяется метод `.groupby()` с указанием (по чему группировать), а затем `.agg()`, где **списком** перичисляем то что хотим посчитать
#
# список состоит из элементов вида `('название', функция)`

# %%
import numpy as np # библиотека Numpy для операций линейной алгебры и прочего

# %%
DF.groupby(['Transmission'],)[num_columns].agg( [ ('median',np.median),
                                    ('std',np.std),
                                    ('Q5%', lambda x: np.percentile(x, q=5)),
                                    ('Q95%',lambda x: np.percentile(x, q=95))])
# Out:
#                 Year                            Distance                       \
#               median       std     Q5%    Q95%    median           std    Q5%
# Transmission
# Automatic     2012.0  6.142240  2001.0  2019.0  150000.0  2.773028e+06  150.0
# Manual        2006.0  8.743167  1991.0  2016.0  185000.0  5.631176e+06    3.0
#
#                        Engine_capacity(cm3)                              \
#                   Q95%               median         std     Q5%    Q95%
# Transmission
# Automatic     320000.0               2000.0  822.260300  1200.0  3500.0
# Manual        395000.0               1590.0  500.260714  1100.0  2400.0
#
#              Price(euro)
#                   median           std     Q5%     Q95%
# Transmission
# Automatic        11600.0  13319.189646  3000.0  36500.0
# Manual            4200.0  69575.339491   900.0  11990.0

# %% [markdown]
# ### Корреляция числовых признаков

# %% [markdown]
# Посмотрим на корреляцию числовых столбцов
#
# `.corr()` для получения матрицы корреляции из DataFrame (нечисловые признаки будут проигнорированы)
#
# `.style.background_gradient(cmap, vmin, vmax)` чтобы подсветить красиво таблицу

# %%
DF[num_columns].corr().style.background_gradient(cmap = 'YlOrRd', # наш цветовой стиль
                                    vmin = -1, # указываем нижний диапазон
                                    vmax=1) # указываем верхний  диапазон
# Out:
# <style type="text/css">
# #T_7b834_row0_col0, #T_7b834_row1_col1, #T_7b834_row2_col2, #T_7b834_row3_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_7b834_row0_col1, #T_7b834_row1_col0 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_7b834_row0_col2, #T_7b834_row2_col0 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_7b834_row0_col3, #T_7b834_row3_col0 {
#   background-color: #fd7435;
#   color: #f1f1f1;
# }
# #T_7b834_row1_col2, #T_7b834_row1_col3, #T_7b834_row2_col1, #T_7b834_row3_col1 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_7b834_row2_col3, #T_7b834_row3_col2 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7b834" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b834_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_7b834_level0_col1" class="col_heading level0 col1" >Distance</th>
#       <th id="T_7b834_level0_col2" class="col_heading level0 col2" >Engine_capacity(cm3)</th>
#       <th id="T_7b834_level0_col3" class="col_heading level0 col3" >Price(euro)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b834_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_7b834_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7b834_row0_col1" class="data row0 col1" >-0.084072</td>
#       <td id="T_7b834_row0_col2" class="data row0 col2" >-0.016698</td>
#       <td id="T_7b834_row0_col3" class="data row0 col3" >0.094408</td>
#     </tr>
#     <tr>
#       <th id="T_7b834_level0_row1" class="row_heading level0 row1" >Distance</th>
#       <td id="T_7b834_row1_col0" class="data row1 col0" >-0.084072</td>
#       <td id="T_7b834_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7b834_row1_col2" class="data row1 col2" >-0.014209</td>
#       <td id="T_7b834_row1_col3" class="data row1 col3" >-0.008938</td>
#     </tr>
#     <tr>
#       <th id="T_7b834_level0_row2" class="row_heading level0 row2" >Engine_capacity(cm3)</th>
#       <td id="T_7b834_row2_col0" class="data row2 col0" >-0.016698</td>
#       <td id="T_7b834_row2_col1" class="data row2 col1" >-0.014209</td>
#       <td id="T_7b834_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7b834_row2_col3" class="data row2 col3" >0.063152</td>
#     </tr>
#     <tr>
#       <th id="T_7b834_level0_row3" class="row_heading level0 row3" >Price(euro)</th>
#       <td id="T_7b834_row3_col0" class="data row3 col0" >0.094408</td>
#       <td id="T_7b834_row3_col1" class="data row3 col1" >-0.008938</td>
#       <td id="T_7b834_row3_col2" class="data row3 col2" >0.063152</td>
#       <td id="T_7b834_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Но статистика не всегда даёт ответы на все вопросы

# %% [markdown]
# ## Категориальные данные
# посмотрим на число повторений результата в каждом категориальном признаке
#
# метод `.nunique()`

# %%
DF[cat_columns].nunique()   # возврашает Series
                            #В роли индексов - название столюцов
                            #значения - количество уникальных значений в столбце
# Out:
# Make             87
# Model           829
# Style            12
# Fuel_type         6
# Transmission      2
# dtype: int64

# %% [markdown]
# Считаем сколько раз каждое значение категории встретчается методом
#
# `.value_counts()`

# %%
DF.Fuel_type.value_counts() # посмотрим на столбец Fuel_type
# Out:
# Diesel            17198
# Petrol            13175
# Metan/Propan       4169
# Hybrid             1976
# Plug-in Hybrid      464
# Electric            282
# Name: Fuel_type, dtype: int64

# %%
DF.Style.value_counts() # посмотрим на столбец Style
# Out:
# Sedan        11437
# Universal     6713
# Hatchback     6091
# Crossover     4383
# SUV           3578
# Minivan       3111
# Coupe          704
# Microvan       488
# Combi          397
# Pickup         172
# Cabriolet      157
# Roadster        33
# Name: Style, dtype: int64

# %% [markdown]
# Оказалось, что часть из наших признаков имеют слишком много записей. Вероятно, редкие из них можно исключить без потери точности. Мы сделаем эту операцию объявив такие записи одним типом - rare.

# %%
counts = DF.Make.value_counts() #  посмотрим на столбец Make

counts  # опять Series
        #В роли Индексов - уникальное значение столбца
        #В роли значений  - сколько раз это значение встречается
# Out:
# Volkswagen      3953
# Mercedes        3501
# Toyota          3427
# BMW             2998
# Renault         2685
#                 ...
# Lamborghini        1
# McLaren            1
# Saturn             1
# Aston Martin       1
# Xpeng              1
# Name: Make, Length: 87, dtype: int64

# %%
counts.median() # оцениваем медиану встречаемости разных признаков
# Out:
# 31.0

# %%
counts[counts<100] # посмотрим на марки которые встречаются реже чем 100 раз
# Out:
# Chrysler            97
# Jeep                94
# GAZ                 82
# Daewoo              79
# Mini                76
# Infiniti            72
# Jaguar              71
# Dodge               66
# Lincoln             57
# Moskvich / Izh      51
# Alfa Romeo          46
# Smart               42
# UAZ                 41
# Ssangyong           34
# Daihatsu            31
# Tesla               28
# Cadillac            27
# Alta marca          27
# Great Wall          21
# Zaz                 20
# Chery               19
# Lancia              18
# Byd                 17
# Brilliance          16
# Saab                15
# Lada                14
# Acura               14
# Lifan               12
# Isuzu               11
# LuAZ                10
# GMC                 10
# Hummer               5
# Bentley              5
# Ravon                5
# Buick                5
# Changan              4
# Maserati             4
# Datsun               3
# Geely                3
# Haima                3
# Scion                3
# Haval                3
# BAIC                 3
# Jac                  3
# Pontiac              2
# Faw                  2
# Mercedes-Maybach     2
# ARO                  2
# Ferrari              1
# Groz                 1
# Abarth               1
# Zotye                1
# Tata                 1
# Lamborghini          1
# McLaren              1
# Saturn               1
# Aston Martin         1
# Xpeng                1
# Name: Make, dtype: int64

# %%
rare =  counts[(counts.values < 25)] # находим все редкие категории
DF['Make'] = DF['Make'].replace(rare.index.values, 'Rare') # заменим все редкие значения на "Rare"
                                # берем индексы, потому что в индексах rare скрыты редкие значения
                                # применяем values чтобы получился массив numpy
DF.Make.value_counts() # пересчитаем сколько кого осталось
# Out:
# Volkswagen        3953
# Mercedes          3501
# Toyota            3427
# BMW               2998
# Renault           2685
# Opel              2220
# Skoda             1892
# Audi              1786
# Ford              1527
# Dacia             1524
# Nissan            1464
# Hyundai           1341
# Honda             1029
# KIA                750
# Mitsubishi         729
# Vaz                654
# Lexus              651
# Volvo              636
# Mazda              539
# Peugeot            469
# Chevrolet          365
# Citroen            337
# Land Rover         313
# Seat               286
# Rare               264
# Fiat               237
# Porsche            204
# Suzuki             176
# Subaru             171
# Rover              115
# Chrysler            97
# Jeep                94
# GAZ                 82
# Daewoo              79
# Mini                76
# Infiniti            72
# Jaguar              71
# Dodge               66
# Lincoln             57
# Moskvich / Izh      51
# Alfa Romeo          46
# Smart               42
# UAZ                 41
# Ssangyong           34
# Daihatsu            31
# Tesla               28
# Cadillac            27
# Alta marca          27
# Name: Make, dtype: int64

# %% [markdown]
# # Библиотеки для визуализации данных

# %%
import matplotlib.pyplot as plt # библиотека MatPlotLib для визуализации
import seaborn as sns # библиотека Seaborn для визуализации данных из Pandas

# %% [markdown]
# Документация библиотеки [matplotlib](https://matplotlib.org/)
#
# Документация библиотеки [seaborn](https://seaborn.pydata.org/)

# %%
plt.style.use('bmh') # выбираем стиль для отрисовки

# %% [markdown]
# [Разные Стили](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)

# %% [markdown]
# ## Гистограммы распределений

# %% [markdown]
# рассмотрим гистограммы (распределение) значений по каждому числовому признаку (столбцу)
#
# Гистограмма seaborn  `.histplot(data, x, bins)`

# %%
# рисуем с помощью библиотеки seaborn
sns.histplot(data=DF, # какой датафрейм используем
            x='Engine_capacity(cm3)', # какую переменную отрисовываем
            bins = 20);  # на сколько ячеек разбиваем

# %% [markdown]
# Чтобы не всё вручную прописывать напишем код который будет делать это за нас

# %%
num_columns
# Out:
# ['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)']

# %%
width = 2
height = int(np.ceil(len(num_columns)/width))
fig, ax = plt.subplots(nrows=height, ncols=width, figsize=(15,8)) # создаем "полотно", на котором будем "рисовать" графики
#     ↑  более точная структура (почти синоним subplot). Говорим что у нас будет height строк и width столбцов

for idx, column_name in enumerate(num_columns): # перебираем все числовые данные
    plt.subplot(height,width, idx+1) #берем конкретную ячейку из заранее подготовленную заготовки
    # рисуем с помощью библиотеки seaborn
    sns.histplot(data=DF, # какой датафрейм используем
            x=column_name, # какую переменную отрисовываем
            bins = 20);  # на сколько ячеек разбиваем

# %% [markdown]
# Столбцы имеют явные аномалии, особенно `Distance` и `Price(euro)`.
#
# Чтобы лучше понять эти аномалии посмотрим на столбцы в логарифмическом масштабе.

# %%
plt.figure(figsize=(10,6)) # создаем "полотно", уточняем размер
sns.histplot(data=DF, # какой датафрейм используем
             x='Price(euro)', # какую переменную отрисовываем
             bins = 20, # на сколько ячеек разбиваем
             log_scale = True); # захотели использовать логарифмический масштаб (для очень больших диапазонов)

# %%
# Удалим те объекты у которых Расстояние равно 0
question_dist = DF[DF.Distance == 0] # через логическое индексирование определяем проблемные данные
DF = DF.drop(question_dist.index) # удаляем данные по проблемным индексам


plt.figure(figsize=(10,6))
sns.histplot(data=DF,
        x='Distance',
        bins = 20,
        log_scale = True);

# %% [markdown]
# Теперь мы можем определить, что нам требуется, чтобы почистить столбцы.
#
# Также, так как задача хорошо интерпретируема мы можем почистить столбцы пользуясь здравым смыслом.
#
# Например, мы можем удалить записи, где цена меньше 100 евро или пробег меньше 1000 км и год старый.

# %%
# здравый смысл
question_dist = DF[(DF.Year <2021) & (DF.Distance < 1100)]
DF = DF.drop(question_dist.index)

# анализ гистограмм
question_dist = DF[(DF.Distance > 0.5e6)]
DF = DF.drop(question_dist.index)

# здравый смысл
question_engine = DF[DF["Engine_capacity(cm3)"] < 200 & (DF.Fuel_type != 'Electric')]
DF = DF.drop(question_engine.index)

# здравый смысл
question_engine = DF[DF["Engine_capacity(cm3)"] > 5000]
DF = DF.drop(question_engine.index)

# здравый смысл
question_price = DF[(DF["Price(euro)"] < 101)]
DF = DF.drop(question_price.index)

# анализ гистограмм
question_price = DF[DF["Price(euro)"] > 0.5e5]
DF = DF.drop(question_price.index)

#анализ гистограмм
question_year = DF[DF.Year < 1971]
DF = DF.drop(question_year.index)

DF = DF.reset_index(drop=True)  # обновим индексы в датафрейме DF. если бы мы прописали drop = False, то была бы еще одна колонка - старые индексы

# %% [markdown]
# Посмотрим на результат

# %%
# аналогично рассмотреному выше примеру, только уже без проблемных данных
width = 2
height = int(np.ceil(len(num_columns)/width))
fig, ax = plt.subplots(nrows=height, ncols=width, figsize=(15,8))

for idx, column_name in enumerate(num_columns):

    plt.subplot(height,width, idx+1)
    sns.histplot(data=DF,
            x=column_name, bins = 20);

# %% [markdown]
# ## Зависимости параметров друг от друга

# %% [markdown]
# pairplot seaborn
# `.pairplot(data, hue, palette)`
#
# по диагонали - гистограммы распределения отдельных признаков
#
# другие элементы - скатерограммы
#
# Важно!
# Если признаков много (больше 5-10) то будет отрисовывать очень долго.
# Поэтому предварительно разбиваем на подгруппы
#
# [Перечень цветовых карт ](https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
sns.pairplot(data = DF,  # какой датафрейм используем
             hue ='Transmission', # какую переменную используем для подкрашиваиния данных.
                                # Рекомендуется использовать Категориальные данные (не очень много уникальных значений)
             palette = 'bwr',); # какую цветовую карту используем. Здесь у нас всего 2 варианта, то мы используем bwr - один из Diverging
                                # если категорий больше, то лучше использовать что-то из Qualitative

# %% [markdown]
# ## Гистограммы распределений (аналог)

# %% [markdown]
# рассмотрим гистограммы (распределение) значений по каждому числовому признаку (столбцу)
#
# Другой способ рисовать гистограммы в seaborn  `.countplot(data, x)`

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.countplot(data=DF, x="Year", hue="Transmission", ax=ax)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# ## Скатерограмма данных

# %% [markdown]
# рассмотрим диаграмму рассеяния (скатерограмму) для двух числовых признаков
#
# Скатерограмма seaborn  `.scatterplot(data, x, y)`

# %%
fig, ax = plt.subplots(1, figsize=(15, 6))
sns.scatterplot(data=DF,
                x='Price(euro)', y='Year',
                hue='Transmission', alpha = 0.6,
                ax=ax)
plt.xscale("log")
plt.xlabel("Price (euro) - log scale");

# %% [markdown]
# ## Violinplot

# %% [markdown]
# Скрипичная диаграмма для оценки распределения числового признака для разных значений категориальных признаков
#
# Скатерограмма seaborn  `.violinplot(data, x, y)`

# %%
fig, ax = plt.subplots(1, figsize=(15, 7))
sns.violinplot(data=DF,
               x="Fuel_type",  y='Price(euro)',
               hue="Transmission", split = True,
               ax=ax);
